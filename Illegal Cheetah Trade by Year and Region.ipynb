# %% [markdown]
# Illegal Cheetah Trade by Year and Region
#
# The largest number of illegal Cheetah Trade happened between 2014 and 2016, which coincides with the West Africa Ebola outbreak and the Zika Virus Epidemic.
#
# ![Illegal_Cheetah_Traded_by_Year_and_Region.PNG](attachment:Illegal_Cheetah_Traded_by_Year_and_Region.PNG)
